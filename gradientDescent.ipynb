# %%
#machine predict, calculate error and learn and then predict again and continues in a loop

#incase of linear reg, it calc the coef and intercepts and then the r2(residual sum of squares) tells it how far off, then it learns and predicts again

# %%
#cost function is used to maximize a process and minimize error

# %% [markdown]
# ## Notebook imports and Packages

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Example 1- A Simple Cost Function
#
# $$f(x)=x^2 + x + 1$$
# ##### LaTex Markdown

# %%
def f(x):
    return x**2+x+1

# %%
#make Data
x_1=np.linspace(start=-3,stop=3,num=10)
print(x_1);
# Out:
# [-3.         -2.33333333 -1.66666667 -1.         -0.33333333  0.33333333
#   1.          1.66666667  2.33333333  3.        ]

# %%
#plot
plt.xlim([-3,3])
plt.ylim(0,8)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)

plt.plot(x_1,f(x_1))

# %%
#the steeper the slow the decrease

# %% [markdown]
# ## Slope & Derivatives

# %%
def df(x):
    return 2*x+1

# %%
def df(x):
    return 2*x+1

# %%
#plot
plt.figure(figsize=[15,5])

#chat 1
plt.subplot(1,2,1)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)

plt.plot(x_1,f(x_1),color='blue',linewidth=5)
#make sure there is a space here

plt.subplot(1,2,2)
plt.xlim([-2,3])
plt.ylim(3,8)
plt.title('Slope function', fontsize=17)

plt.grid()
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.show()

# %% [markdown]
# ## Python Loops & Gradient Descent

# %%
#python for loops
for n in range(5):
    print('Hello world',n)
# Out:
# Hello world 0
# Hello world 1
# Hello world 2
# Hello world 3
# Hello world 4

# %%
# python while loop
counter=0
while counter<7:
    print('counting...',counter)
    counter= counter + 1
print('Ready or not here i come')
# Out:
# counting... 0
# counting... 1
# counting... 2
# counting... 3
# counting... 4
# counting... 5
# counting... 6
# Ready or not here i come

# %%
new_x=3
previous_x=0;
step_multiplier=0.1
precision=0.0001
x_list=[new_x]
slope_list=[df(new_x)]

for n in range(500):
    previous_x=new_x
    gradient=df(previous_x)
    new_x=previous_x-step_multiplier *gradient
    x_list.append(new_x)
    slope_list.append(new_x)
    print('new_x',new_x)
    print('  ')
    step_size=abs(new_x-previous_x)
    print('step',step_size)
    
    
    if(step_size<precision):
        break
    
print('Local minimum occurs at:',new_x)    
print('Slope value at this point is:',df(new_x))  
print('f(x) or cost at this point is:',f(new_x))  
#a steep slope indicates an increase in error the closer we are to the minimum slope the lesser the erro
# Out:
# new_x 2.3
#
# step 0.7000000000000002
# new_x 1.7399999999999998
#
# step 0.56
# new_x 1.2919999999999998
#
# step 0.44799999999999995
# new_x 0.9335999999999998
#
# step 0.35840000000000005
# new_x 0.6468799999999998
#
# step 0.28672
# new_x 0.41750399999999976
#
# step 0.22937600000000002
# new_x 0.2340031999999998
#
# step 0.18350079999999996
# new_x 0.08720255999999982
#
# step 0.14680063999999998
# new_x -0.03023795200000015
#
# step 0.11744051199999997
# new_x -0.12419036160000013
#
# step 0.09395240959999998
# new_x -0.1993522892800001
#
# step 0.07516192767999996
# new_x -0.25948183142400005
#
# step 0.06012954214399996
# new_x -0.30758546513920004
#
# step 0.04810363371519999
# new_x -0.34606837211136005
#
# step 0.03848290697216
# new_x -0.376854697689088
#
# step 0.03078632557772798
# new_x -0.4014837581512704
#
# step 0.024629060462182384
# new_x -0.4211870065210163
#
# step 0.019703248369745907
# new_x -0.43694960521681303
#
# step 0.015762598695796715
# new_x -0.44955968417345044
#
# step 0.012610078956637405
# new_x -0.45964774733876035
#
# step 0.010088063165309913
# new_x -0.46771819787100827
#
# step 0.00807045053224792
# new_x -0.4741745582968066
#
# step 0.006456360425798335
# new_x -0.47933964663744527
#
# step 0.005165088340638668
# new_x -0.4834717173099562
#
# step 0.0041320706725109235
# new_x -0.48677737384796493
#
# step 0.003305656538008739
# new_x -0.48942189907837197
#
# step 0.0026445252304070355
# new_x -0.49153751926269756
#
# step 0.002115620184325595
# new_x -0.49323001541015804
#
# step 0.001692496147460476
# new_x -0.49458401232812643
#
# step 0.001353996917968392
# new_x -0.4956672098625011
#
# step 0.0010831975343746914
# new_x -0.4965337678900009
#
# step 0.0008665580274997975
# new_x -0.4972270143120007
#
# step 0.0006932464219998047
# new_x -0.4977816114496006
#
# step 0.000554597137599866
# new_x -0.49822528915968045
#
# step 0.00044367771007985946
# new_x -0.49858023132774437
#
# step 0.00035494216806392087
# new_x -0.4988641850621955
#
# step 0.0002839537344511145
# new_x -0.4990913480497564
#
# step 0.0002271629875609249
# new_x -0.4992730784398051
#
# step 0.00018173039004870661
# new_x -0.4994184627518441
#
# step 0.0001453843120389764
# new_x -0.4995347702014753
#
# step 0.00011630744963120332
# new_x -0.49962781616118024
#
# step 9.304595970494045e-05
# Local minimum occurs at: -0.49962781616118024
# Slope value at this point is: 0.0007443676776395236
# f(x) or cost at this point is: 0.7500001385208099

# %%
#superimpose gradient descent calculation

#plot
plt.figure(figsize=[20,5])

#chat 1
plt.subplot(1,2,1)

plt.xlim([-3,3])
plt.ylim(0,8)

plt.title('Cost function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)

plt.plot(x_1,f(x_1),color='blue',linewidth=5)
values=np.array(x_list)
plt.scatter(x_list,f(values),color='red',s=100)
#make sure there is a space here
type(slope_list)plt.subplot(1,2,2)
plt.xlim([-2,3])
plt.ylim(-3,6)
plt.title('Slope function', fontsize=17)

plt.grid()
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)
plt.scatter(x_list,slope_list,color='red',s=300)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.show()
# Out:
#   Input In [30]
#     type(slope_list)plt.subplot(1,2,2)
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Example-2 Multiple Minima vs Initial Guess & Advance Functions

# %% [markdown]
# $$g(x)=x^4 -4x^2+5$$

# %%
x_2=np.linspace(-2,2,1000)

# %%
def g(x):
    return x**4-4*x**2 +5

# %%
def dg(x):
    return 4*x**3 -8*x

# %%
#superimpose gradient descent calculation

#plot
plt.figure(figsize=[15,5])

#chat 1
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)

plt.plot(x_2,g(x_2),color='blue',linewidth=5)
values=np.array(x_list)
# plt.scatter(x_list,f(values),color='red',s=100)

# make sure there is a space here

# type(slope_list)
plt.subplot(1,2,2)

plt.title('Slope function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.grid()
plt.xlim([-2,2])
plt.ylim(-6,8)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5)

# # plt.scatter(x_list,slope_list,color='red',s=300)

# plt.show()

# %% [markdown]
# # Gradient Dresent as a Function

# %%
def gradient_desecent(derivative_func,initial ,multiplier=0.02,precision=0.001,max_iter=300):
    
    new_x=initial

   

    x_list=[new_x]
    slope_list=[derivative_func(new_x)]

    for n in range(max_iter):
        previous_x=new_x
        gradient=derivative_func(previous_x)
        new_x=previous_x-multiplier *gradient
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
#         print('new_x',new_x)
#         print('  ')
        step_size=abs(new_x-previous_x)
#         print('step',step_size)


        if(step_size<precision):
        
            break
    return new_x,x_list,slope_list        

   
#     print('Slope value at this point is:',df(new_x))  
#     print('f(x) or cost at this point is:',f(new_x))  
    #a steep slope indicates an increase in error the closer we are to the minimum slope the lesser the erro

# %%
local_min,list_x,deriv_list =gradient_desecent(derivative_func=dg,initial=0.5,multiplier=0.02,precision=0.001)
print('Local minimum occurs at:',local_min) 
print('number of steps',len(list_x))
# Out:
# Local minimum occurs at: 1.4122375085019094
# number of steps 23

# %%
local_min,list_x,deriv_list =gradient_desecent(derivative_func=dg,initial=0.1)
print('Local minimum occurs at:',local_min) 
print('number of steps',len(list_x))
# Out:
# Local minimum occurs at: 1.4120887490901561
# number of steps 34

# %%
local_min,list_x,deriv_list =gradient_desecent(derivative_func=dg,initial=0)
print('Local minimum occurs at:',local_min) 
print('number of steps',len(list_x))
# Out:
# Local minimum occurs at: 0.0
# number of steps 2

# %%
#superimpose gradient descent calculation

#plot
plt.figure(figsize=[20,5])

#chat 1
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)

plt.plot(x_2,g(x_2),color='blue',linewidth=5)
values=np.array(list_x)
plt.scatter(list_x,g(values),color='red',s=100,alpha=0.6)
#make sure there is a space here


#Chart: derivative

plt.subplot(1,2,2)

plt.title('Slope of the cost function',fontsize=17)

plt.xlabel('x',fontsize=16)

plt.ylabel('dg(x)',fontsize=16)

plt.grid()

plt.xlim([-2,2])

plt.ylim(-6,8)

plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5)

plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.6)

# %% [markdown]
# # Divergence, Overflow and Python Tupules

# %%
#,make data
x_3=np.linspace(start=-2.5, stop=2.5,num=1000)
def h(x):
    return x**5-2*x**4+2
def dh(x):
    return 5*x**4-8*x**3

# %%
local_min,list_x,deriv_list =gradient_desecent(derivative_func=dg,initial=-0.2,max_iter=10)
print('Local minimum occurs at:',local_min) 
print('number of steps',len(list_x))
# Out:
# Local minimum occurs at: -0.77256904663799
# number of steps 11

# %%
#superimpose gradient descent calculation

#plot
plt.figure(figsize=[20,5])

#chat 1
plt.subplot(1,2,1)

plt.xlim([-1.2,2.5])
plt.ylim(-1,4)

plt.title('Cost function', fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)

plt.plot(x_3,h(x_3),color='blue',linewidth=5)
values=np.array(list_x)
plt.scatter(list_x,h(values),color='red',s=100,alpha=0.6)
#make sure there is a space here


#Chart: derivative

plt.subplot(1,2,2)
plt.xlim([-1,2])

plt.ylim(-4,5)

plt.title('Slope of the cost function',fontsize=17)

plt.xlabel('x',fontsize=16)

plt.ylabel('dh(x)',fontsize=16)

plt.grid()



plt.plot(x_3,dh(x_3),color='skyblue',linewidth=5)

plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.6)
plt.show()

# %%
import sys
sys.version

sys.float_info.max
# Out:
# 1.7976931348623157e+308
